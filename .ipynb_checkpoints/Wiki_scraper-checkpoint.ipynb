# %%
import pandas as pd
import numpy as np

# %%
from bs4 import BeautifulSoup
import re
import requests

# %%
URL = 'https://en.wikipedia.org/wiki/Category:Indian_politicians_by_city_or_town'

page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')
l = []
for a in soup.find_all('a', {'href':re.compile('^/wiki/Category')}):
    l.append(a['href'])
l[:4]
# Out:
# ['/wiki/Category:Container_categories',
#  '/wiki/Category:Mayors_by_city_in_India',
#  '/wiki/Category:Kerala_politicians_by_city',
#  '/wiki/Category:Uttar_Pradesh_politicians_by_city']

# %%
l1 = []
for i in l:
    page = requests.get('https://en.wikipedia.org/{}'.format(i), timeout=10)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    for a in soup.find_all('a', {'href':re.compile('^/wiki/Category')}):
        l1.append(a['href'])

# %%
l2 = []
for i in l1:
    page = requests.get('https://en.wikipedia.org/{}'.format(i), timeout=10)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    for a in soup.find_all('a', {'href':re.compile('^/wiki/')}):
        with open('links_final.txt','a') as f:
            f.write(a['href']+'\n')

# %%
list_of_info = []

# %%
def extractinfo(page):
    page = requests.get('https://en.wikipedia.org/{}'.format(page), timeout=10)
    # page = requests.get(articleUrl_final, timeout=10)
    soup = BeautifulSoup(page.content, 'html.parser')

    try:
        try:
            global row_img
            for img in soup('td',{'class':'infobox-image'}):
                img_link = img.find_all('a',{'class':'image'})
                for i in img_link:
                    row_img = i.find('img')['src']
        except Excepation as e:
            row_img=e

        try:
            born = soup.find_all('span',{'style':'display:none'})[0].text
        except Exception as e:
            born = 0

        try:
            died = soup.find_all('span',{'style':'display:none'})[1].text
        except Exception as e:
            died = 0

        dict_final = {
            'Name' : soup.find('h1',{'class':'firstHeading mw-first-heading'}).text,
            'born' : born,
            'died': died,
            'img_link' : 'https:{}'.format(row_img)
        }
        list_of_info.append(dict_final)

    except Exception as e:
            print(e)

# %%
list_links = []
with open('links_final.txt','r') as file:
    wiki = file.read()
    list_links.append(wiki.split('\n'))
list_final = np.concatenate(list_links)
# Out:
# 4481

# %%
for i in list_final:
    print(f"Running for article {i}")
    extractinfo(i)
# Out:
# Running for article /wiki/Dinkar_Mehta
# name 'row_img' is not defined
# Running for article /wiki/Ramanbhai_Neelkanth
# Running for article /wiki/Meenakshi_Patel
# Running for article /wiki/Amit_Shah_(mayor)
# Running for article /wiki/Gautam_Shah
# Running for article /wiki/Kanaji_Thakor
# Running for article /wiki/Asit_Vora
# Running for article /wiki/List_of_mayors_of_Allahabad
# Running for article /wiki/Rita_Bahuguna_Joshi
# Running for article /wiki/Abhilasha_Gupta
# Running for article /wiki/Bishambhar_Nath_Pande
# Running for article /wiki/List_of_mayors_of_Bangalore
# Running for article /wiki/Mumtaz_Begum_(mayor)
# Running for article /wiki/Prema_Cariappa
# Running for article /wiki/K._P._Puttanna_Chetty
# Running for article /wiki/Lawrence_Fernandes
# Running for article /wiki/V._S._Krishna_Iyer
# Running for article /wiki/M._Krishnappa_(politician,_born_1918)
# Running for article /wiki/M_Goutham_Kumar
# Running for article /wiki/Gangambike_Mallikarjun
# Running for article /wiki/D._Venkatesh_Murthy
# Running for article /wiki/V._P._Deenadayalu_Naidu
# Running for article /wiki/G._Padmavathi
# Running for article /wiki/R._Subbanna
# Running for article /wiki/R._Sampath_Raj
# Running for article /wiki/Sharadamma_Ramanjaneya
# Running for article /wiki/Manjunath_Reddy
# Running for article /wiki/N._Shanthakumari
# Running for article /wiki/List_of_mayors_of_Chennai
# Running for article /wiki/V._Balasundaram
# Running for article /wiki/Muhammad_Bazullah
# Running for article /wiki/C._Basudev
# Running for article /wiki/Vengal_Chakkarai
# Running for article /wiki/P._V._Cherian
# Running for article /wiki/Tara_Cherian
# Running for article /wiki/S._Rm._M._Annamalai_Chettiar
# Running for article /wiki/R._Ramanathan_Chettiar
# Running for article /wiki/G._Janakiram_Chetty
# Running for article /wiki/M._A._Chidambaram
# Running for article /wiki/C._Chittibabu
# Running for article /wiki/Saidai_Duraisamy
# Running for article /wiki/S._A._Ganesan
# Running for article /wiki/Habibullah_Baig
# Running for article /wiki/Abdul_Hameed_Khan
# Running for article /wiki/Nathaniel_Higginson
# Running for article /wiki/V._R._Ramanatha_Iyer
# Running for article /wiki/J._Venkatanarayana_Naidu
# Running for article /wiki/Kamakshi_Jayaraman
# Running for article /wiki/K._Kamalakannan
# Running for article /wiki/M._S._Abdul_Khader
# Running for article /wiki/U._Krishna_Rao
# Running for article /wiki/G._Kuchelar
# Running for article /wiki/P._T._Kumarasamy_Chetty
# Running for article /wiki/W._W._Ladden
# Running for article /wiki/M._Radhakrishna_Pillai
# Running for article /wiki/R._Sivasankar_Mehta
# Running for article /wiki/C._Tadulinga_Mudaliar
# Running for article /wiki/Arcot_Ramasamy_Mudaliar
# Running for article /wiki/M._A._Muthiah_Chettiar
# Running for article /wiki/K._Sriramulu_Naidu
# Running for article /wiki/Josias_Du_Pr%C3%A9_Porcher
# Running for article /wiki/S._Ramaswamy_Naidu
# Running for article /wiki/S._Krishnamurthy
# Running for article /wiki/S._Satyamurti
# Running for article /wiki/J._Shivashanmugam_Pillai
# Running for article /wiki/C._H._Sibghatullah
# Running for article /wiki/N._Sivaraj
# Running for article /wiki/K._N._Srinivasan
# Running for article /wiki/M._K._Stalin
# Running for article /wiki/Ma._Subramanian
# Running for article /wiki/Syed_Niamatullah
# Running for article /wiki/T._Sundara_Rao_Naidu
# Running for article /wiki/V._Thirumalai_Pillai
# Running for article /wiki/K._Venkataswami_Naidu
# Running for article /wiki/List_of_mayors_of_Coimbatore
# Running for article /wiki/A._Kalpana
# Running for article /wiki/T._Malaravan
# Running for article /wiki/Ganapathi_P._Raj_Kumar
# Running for article /wiki/V._Gopalakrishnan_(mayor)
# Running for article /wiki/S._M._Velusamy
# Running for article /wiki/Rajni_Abbi
# Running for article /wiki/Nuruddin_Ahmed
# Running for article /wiki/Aruna_Asaf_Ali
# Running for article /wiki/Anita_Arya
# Running for article /wiki/H._K._L._Bhagat
# Running for article /wiki/Lala_Hansraj_Gupta
# Running for article /wiki/Arti_Mehra
# Running for article /wiki/Kidar_Nath_Sahani
# Running for article /wiki/Satbir_Singh_(politician)
# Running for article /wiki/Mayor_of_Hyderabad,_India
# Running for article /wiki/Rani_Kumudini_Devi
# Running for article /wiki/Mohammad_Majid_Hussain
# Running for article /wiki/List_of_mayors_of_Hyderabad
# Running for article /wiki/Krishna_Swamy_Mudiraj
# Running for article /wiki/Laxminarayana_Mudiraj
# Running for article /wiki/Bonthu_Rammohan
# Running for article /wiki/Madapati_Hanumantha_Rao
# Running for article /wiki/Banda_Karthika_Reddy
# Running for article /wiki/Sarojini_Pulla_Reddy
# Running for article /wiki/Gadwal_Vijayalakshmi
# Running for article /wiki/Syed_Badrudduja
# Running for article /wiki/Kamal_Basu
# Running for article /wiki/Bikash_Ranjan_Bhattacharya
# Running for article /wiki/Subhas_Chandra_Bose
# Running for article /wiki/Sovan_Chatterjee
# Running for article /wiki/Chittaranjan_Das
# Running for article /wiki/Shyam_Sundar_Gupta
# Running for article /wiki/Firhad_Hakim
# Running for article /wiki/A._K._Fazlul_Huq
# Running for article /wiki/List_of_mayors_of_Kolkata
# Running for article /wiki/Bidhan_Chandra_Roy
# Running for article /wiki/Nalini_Ranjan_Sarkar
# Running for article /wiki/Jatindra_Mohan_Sengupta
# Running for article /wiki/Prasanta_Sur
# Running for article /wiki/Jagatvir_Singh_Drona
# Running for article /wiki/Pramila_Pandey
# Running for article /wiki/M._Bhaskaran
# Running for article /wiki/V._K._C._Mammed_Koya
# Running for article /wiki/List_of_mayors_of_Kozhikode
# Running for article /wiki/A._K._Premajam
# Running for article /wiki/Sanyukta_Bhatia
# Running for article /wiki/Akhilesh_Das
# Running for article /wiki/Ved_Rattan_Mohan
# Running for article /wiki/S_C_Rai
# Running for article /wiki/Dinesh_Sharma_(politician)
# Running for article /wiki/Gulzar_Banu
# Running for article /wiki/Blasius_D%27Souza
# Running for article /wiki/Rajani_Duganna
# Running for article /wiki/Lawrence_Fernandes
# Running for article /wiki/Praveen_Kumar_(Mangalore_politician)
# Running for article /wiki/List_of_mayors_of_Vijayawada
# Running for article /wiki/Rayana_Bhagya_Lakshmi
# Running for article /wiki/List_of_mayors_of_Vijayawada
# Running for article /wiki/List_of_mayors_of_Mumbai
# Running for article /wiki/Snehal_Ambekar
# Running for article /wiki/Joseph_Baptista
# Running for article /wiki/Chhagan_Bhujbal
# Running for article /wiki/Nana_Chudasama
# Running for article /wiki/Datta_Dalvi
# Running for article /wiki/Mahadeo_Deole
# Running for article /wiki/Murli_Deora
# Running for article /wiki/Chandrakant_Handore
# Running for article /wiki/Shraddha_Jadhav
# Running for article /wiki/Manohar_Joshi
# Running for article /wiki/Sudhir_Joshi_(politician)
# Running for article /wiki/Vishwanath_Mahadeshwar
# Running for article /wiki/Wamanrao_Mahadik
# Running for article /wiki/Yusuf_Meherally
# Running for article /wiki/Asoka_Mehta
# Running for article /wiki/S.S._Mirajkar
# Running for article /wiki/Sulochana_Modi
# Running for article /wiki/Dattaji_Nalawade
# Running for article /wiki/Khurshed_Nariman
# Running for article /wiki/Dahyabhai_Patel
# Running for article /wiki/Shanti_Patel
# Running for article /wiki/S._K._Patil
# Running for article /wiki/Kishori_Pednekar
# Running for article /wiki/Nirmala_Samant_Prabhavalkar
# Running for article /wiki/Ramesh_Prabhoo
# Running for article /wiki/Sunil_Prabhu
# Running for article /wiki/Hoosenally_Rahimtoola
# Running for article /wiki/Ibrahim_Rahimtoola
# Running for article /wiki/Jaffer_Rahimtoola
# Running for article /wiki/Diwakar_Raote
# Running for article /wiki/Shubha_Raul
# Running for article /wiki/Vishakha_Raut
# Running for article /wiki/R._R._Singh
# Running for article /wiki/Milind_Vaidya
# Running for article /wiki/Mira_Aggarwal
# Running for article /wiki/Master_Azad_Singh
# Running for article /wiki/Pravin_Datke
# Running for article /wiki/Dayashankar_Tiwari
# Running for article /wiki/Devendra_Fadnavis
# Running for article /wiki/Ramratan_Janorkar
# Running for article /wiki/Nanda_Jichkar
# Running for article /wiki/List_of_mayors_of_Nagpur
# Running for article /wiki/Anil_Sole
# Running for article /wiki/S._K._Wankhede
# Running for article /wiki/List_of_mayors_of_Pune
# Running for article /wiki/Hari_Narayan_Apte
# Running for article /wiki/Vaishali_Bankar
# Running for article /wiki/Girish_Bapat
# Running for article /wiki/Vandana_Chavan
# Running for article /wiki/Dattatray_Dhankawade
# Running for article /wiki/Datta_Ekbote
# Running for article /wiki/Narayan_Ganesh_Gore
# Running for article /wiki/Narasimha_Chintaman_Kelkar
# Running for article /wiki/Murlidhar_Mohol
# Running for article /wiki/Mukta_Tilak
# Running for article /wiki/Bhai_Vaidya
# Running for article /wiki/List_of_mayors_of_Surat
# Running for article /wiki/Rajendra_Desai
# Running for article /wiki/Jagdish_Patel
# Running for article /wiki/Kashiram_Rana
# Running for article /wiki/List_of_mayors_of_Salem,_Tamil_Nadu
# Running for article /wiki/A._Ramachandran_(politician)
# Running for article /wiki/S._Soundappan
# Running for article /wiki/Sarita_Chaudhary
# Running for article /wiki/Savita_Gupta
# Running for article /wiki/Mukesh_Suryan
# Running for article /wiki/Naresh_Mhaske
# Running for article /wiki/Sanjay_More
# Running for article /wiki/Satish_Pradhan
# Running for article /wiki/Meenakshi_Shinde
# Running for article /wiki/Anant_Tare
# Running for article /wiki/Rajan_Vichare
# Running for article /wiki/R._Bindu
# Running for article /wiki/Ajitha_Jayarajan
# Running for article /wiki/Jose_Kattukkaran
# Running for article /wiki/Rajan_Pallan
# Running for article /wiki/I._P._Paul
# Running for article /wiki/Ajitha_Vijayan
# Running for article /wiki/List_of_mayors_of_Varanasi
# Running for article /wiki/Mridula_Jaiswal
# Running for article /wiki/Kaushalendra_Singh
# Running for article /wiki/Kamichetty_Savithri
# Running for article /wiki/Samatam_Kistaya
# Running for article /wiki/Bezawada_Bapanaya_Naidou
# Running for article /wiki/Kamichetty_Venougopala_Rao_Naidou
# Running for article /wiki/Ravi_Kant_Sharma
# Running for article /wiki/Arun_Sood
# Running for article /wiki/List_of_mayors_of_Ahmedabad
# Running for article /wiki/List_of_mayors_of_Nagpur
# Running for article /wiki/List_of_mayors_of_Yanam
# Running for article /wiki/List_of_the_youngest_mayors_in_India
# Running for article /wiki/India
# Running for article /wiki/List_of_mayors_of_Ahmedabad
# Running for article /wiki/List_of_mayors_of_Nagpur
# Running for article /wiki/List_of_mayors_of_Yanam
# Running for article /wiki/List_of_the_youngest_mayors_in_India
# Running for article /wiki/Kerala
# Running for article /wiki/States_and_territories_of_India
# Running for article /wiki/India
# Running for article /wiki/South_India
# Running for article /wiki/Kerala
# Running for article /wiki/Kerala
# Running for article /wiki/2021_Nipah_virus_outbreak_in_Kerala
# Running for article /wiki/Battle_of_Pookkottur
# Running for article /wiki/Dakshayani_Velayudhan_Award
# Running for article /wiki/Ezhuvathiruthy
# Running for article /wiki/Government_Mental_Health_Centre,_Kozhikode
# Running for article /wiki/High_Range,_Kerala
# Running for article /wiki/Indian_Radical_Painters%27_and_Sculptors%27_Association
# Running for article /wiki/Kadampattukonam
# Running for article /wiki/Kallekulangara
# Running for article /wiki/Kanan_Devan_Hills_Plantations_Company
# Running for article /wiki/Kerala_Lokayukta
# Running for article /wiki/KochuKadavu
# Running for article /wiki/Kottayam
# Running for article /wiki/Kozhikode_City_Police
# Running for article /wiki/List_of_candidates_for_the_2019_Indian_general_election_in_Kerala
# Running for article /wiki/List_of_rail_tunnels_in_Kerala
# Running for article /wiki/Madathara
# Running for article /wiki/Mamala
# Running for article /wiki/Firoz_Merchant
# Running for article /wiki/Miss_Kerala_2019
# Running for article /wiki/Moonnalam
# Running for article /wiki/RJ_Shaan
# Running for article /wiki/Vallabhankunnu
# Running for article /wiki/A._K._Antony
# Running for article /wiki/K._R._Gouri_Amma
# Running for article /wiki/Raja_Kesavadas
# Running for article /wiki/K._N._P._Kurup
# Running for article /wiki/K._S._Manoj
# Running for article /wiki/P._K._Medini
# Running for article /wiki/K._K._Nayar
# Running for article /wiki/S._Ramachandran_Pillai
# Running for article /wiki/M._I._Shanavas
# Running for article /wiki/C._S._Sujatha
# Running for article /wiki/T._V._Thomas
# Running for article /wiki/A._V._Thamarakshan
# Running for article /wiki/Subash_Vasu
# Running for article /wiki/A._P._Abdullakutty
# Running for article /wiki/N._E._Balaram
# Running for article /wiki/A._K._Gopalan
# Running for article /wiki/T._Govindan
# Running for article /wiki/K._Karunakaran
# Running for article /wiki/K._A._Keraleeyan
# Running for article /wiki/E._K._Nayanar
# Running for article /wiki/M._T._Padma
# Running for article /wiki/Azhikodan_Raghavan
# Running for article /wiki/M._V._Raghavan
# Running for article /wiki/T._V._Rajesh
# Running for article /wiki/P._Santhosh_Kumar
# Running for article /wiki/A._K._Saseendran
# Running for article /wiki/A._N._Shamseer
# Running for article /wiki/K._C._Abraham
# Running for article /wiki/Sahodaran_Ayyappan
# Running for article /wiki/K._Babu
# Running for article /wiki/Benny_Behanan
# Running for article /wiki/M._A._Chakko
# Running for article /wiki/Joy_Cherian
# Running for article /wiki/M._T._Jacob
# Running for article /wiki/Soumini_Jain
# Running for article /wiki/Roji_M_John
# Running for article /wiki/A._C._Jose
# Running for article /wiki/Babu_Mathew_P._Joseph
# Running for article /wiki/M._C._Josephine
# Running for article /wiki/P._J._Joy
# Running for article /wiki/Thottakkattu_Madhaviamma
# Running for article /wiki/Jamal_Manakkadan
# Running for article /wiki/C._K._Manisankar
# Running for article /wiki/K._J._Maxi
# Running for article /wiki/Paliath_Achan
# Running for article /wiki/Sebastian_Paul
# Running for article /wiki/P._Govinda_Pillai
# Running for article /wiki/T._K._Ramakrishnan
# Running for article /wiki/Anwar_Sadath
# Running for article /wiki/Abraham_Barak_Salem
# Running for article /wiki/Meera_Sanyal
# Running for article /wiki/P._P._Thankachan
# Running for article /wiki/K._V._Thomas
# Running for article /wiki/K._P._Vallon
# Running for article /wiki/Mercy_Williams
# Running for article /wiki/Henry_Austin_(Indian_politician)
# Running for article /wiki/Sabitha_Beegam
# Running for article /wiki/Honey_Benjamin
# Running for article /wiki/T._K._Divakaran
# Running for article /wiki/P._K._Gurudasan
# Running for article /wiki/C._Kesavan
# Running for article /wiki/G._Janardhana_Kurup
# Running for article /wiki/Chalakuzhy_Paulose_Mathen
# Running for article /wiki/Murali_(Malayalam_actor)
# Running for article /wiki/M._Noushad
# Running for article /wiki/V._P._Ramakrishna_Pillai
# Running for article /wiki/A._A._Rahim
# Running for article /wiki/J._Chinchu_Rani
# Running for article /wiki/Kumbalathu_Sanku_Pillai
# Running for article /wiki/K._Somaprasad
# Running for article /wiki/Rajmohan_Unnithan
# Running for article /wiki/T._M._Varghese
# Running for article /wiki/K._M._Abraham
# Running for article /wiki/Anto_Antony
# Running for article /wiki/P._K._Biju
# Running for article /wiki/Oommen_Chandy
# Running for article /wiki/Thomas_Chazhikadan
# Running for article /wiki/Accamma_Cherian
# Running for article /wiki/P._C._George
# Running for article /wiki/V._N._Janaki
# Running for article /wiki/Alphons_Kannanthanam
# Running for article /wiki/Cherian_J._Kappan
# Running for article /wiki/K._Suresh_Kurup
# Running for article /wiki/Jose_K._Mani
# Running for article /wiki/P._T._Chacko
# Running for article /wiki/Changanassery_Parameswaran_Pillai
# Running for article /wiki/Mannathu_Padmanabha_Pillai
# Running for article /wiki/Anita_Pratap
# Running for article /wiki/George_Thomas_(Indian_politician)
# Running for article /wiki/Vaikom_Viswan
# Running for article /wiki/P._M._Aboobacker
# Running for article /wiki/K._Ajitha
# Running for article /wiki/A._K._Balan
# Running for article /wiki/Ramya_Haridas
# Running for article /wiki/M._Kamalam
# Running for article /wiki/C._H._Mohammed_Koya
# Running for article /wiki/P._P._Ummer_Koya
# Running for article /wiki/List_of_mayors_of_Kozhikode
# Running for article /wiki/John_Matthai
# Running for article /wiki/K._P._K._Menon
# Running for article /wiki/M._K._Muneer
# Running for article /wiki/S._K._Pottekkatt
# Running for article /wiki/A._K._Premajam
# Running for article /wiki/M._K._Raghavan
# Running for article /wiki/Mullappally_Ramachandran
# Running for article /wiki/S._K._Sajeesh
# Running for article /wiki/P._Sankaran
# Running for article /wiki/A._K._Saseendran
# Running for article /wiki/P._Sathidevi
# Running for article /wiki/T_Siddique
# Running for article /wiki/Binoy_Viswam
# Running for article /wiki/V._R._Krishna_Iyer
# Running for article /wiki/N._N._Krishnadas
# Running for article /wiki/T._M._Nair
# Running for article /wiki/M._B._Rajesh
# Running for article /wiki/K._Seshadri_Iyer
# Running for article /wiki/T._N._Seshan
# Running for article /wiki/K._Ansalan
# Running for article /wiki/Ayyankali
# Running for article /wiki/C._Jayan_Babu
# Running for article /wiki/Thalekunnil_Basheer
# Running for article /wiki/Sethu_Lakshmi_Bayi
# Running for article /wiki/Vakkom_Bharathan
# Running for article /wiki/A._Charles
# Running for article /wiki/C._Divakaran
# Running for article /wiki/B._Ekbal
# Running for article /wiki/K._B._Ganesh_Kumar
# Running for article /wiki/Shobhana_George
# Running for article /wiki/C._K._Hareendran
# Running for article /wiki/M._M._Hassan
# Running for article /wiki/Jagadish_Kumar
# Running for article /wiki/V._Joy
# Running for article /wiki/Elamaram_Kareem
# Running for article /wiki/G._Karthikeyan
# Running for article /wiki/P._Karunakaran
# Running for article /wiki/J._Thomas_Kayalackakom
# Running for article /wiki/Krishna_Kumar_(actor)
# Running for article /wiki/T._A._Majeed
# Running for article /wiki/Vakkom_Majeed
# Running for article /wiki/Annie_Mascarene
# Running for article /wiki/Lakshmi_N._Menon
# Running for article /wiki/D._K._Murali
# Running for article /wiki/Pirappancode_Murali
# Running for article /wiki/N._J._Kuncheria
# Running for article /wiki/P._T._Chacko
# Running for article /wiki/Cherian_Philip
# Running for article /wiki/Vakkom_Purushothaman
# Running for article /wiki/Varkala_Radhakrishnan
# Running for article /wiki/Arya_Rajendran
# Running for article /wiki/Lenin_Rajendran
# Running for article /wiki/Pannyan_Raveendran
# Running for article /wiki/Thampanoor_Ravi
# Running for article /wiki/N._Sakthan
# Running for article /wiki/Anirudhan_Sampath
# Running for article /wiki/I._B._Sathish
# Running for article /wiki/R._Selvaraj_(politician)
# Running for article /wiki/V._Sivankutty
# Running for article /wiki/Pandalam_Sudhakaran
# Running for article /wiki/K._V._Surendranath
# Running for article /wiki/Pattom_A._Thanu_Pillai
# Running for article /wiki/P._G._N._Unnithan
# Running for article /wiki/M._A._Vaheed
# Running for article /wiki/M._Vijayakumar
# Running for article /wiki/P._C._Vishnunadh
# Running for article /wiki/Anil_Akkara
# Running for article /wiki/Janaki_Amma
# Running for article /wiki/P._A._Antony
# Running for article /wiki/A._V._Aryan
# Running for article /wiki/P._Balachandran_(politician)
# Running for article /wiki/R._Bindu
# Running for article /wiki/P._C._Chacko
# Running for article /wiki/Iyyunni_Chalakka
# Running for article /wiki/Xavier_Chittilappilly
# Running for article /wiki/Devan_(actor)
# Running for article /wiki/B._D._Devassy
# Running for article /wiki/K._P._Dhanapalan
# Running for article /wiki/V._R._Krishnan_Ezhuthachan
# Running for article /wiki/P._P._George
# Running for article /wiki/E._Ikkanda_Warrier
# Running for article /wiki/Innocent_(actor)
# Running for article /wiki/T._S._Narayana_Iyer
# Running for article /wiki/C._R._Iyyunni
# Running for article /wiki/C._Janardhanan
# Running for article /wiki/Sarah_Joseph_(author)
# Running for article /wiki/K._Karunakaran
# Running for article /wiki/K._V._Abdul_Khader
# Running for article /wiki/Mithavaadi_Krishnan
# Running for article /wiki/V._R._Sunil_Kumar
# Running for article /wiki/Savithri_Lakshmanan
# Running for article /wiki/P._A._Madhavan
# Running for article /wiki/A._R._Menon
# Running for article /wiki/C._Achutha_Menon
# Running for article /wiki/T._Sankunni_Menon
# Running for article /wiki/K._Muraleedharan
# Running for article /wiki/T._K._Nair
# Running for article /wiki/Lonappan_Nambadan
# Running for article /wiki/Kurur_Neelakandan_Namboodiripad
# Running for article /wiki/C._R._Neelakandan
# Running for article /wiki/Babu_M._Palissery
# Running for article /wiki/A._M._Paraman
# Running for article /wiki/Raghavan_Pozhakadavil
# Running for article /wiki/K._Radhakrishnan_(politician)
# Running for article /wiki/V._V._Raghavan
# Running for article /wiki/K._Rajan_(politician)
# Running for article /wiki/K._A._Rajan
# Running for article /wiki/K._P._Rajendran
# Running for article /wiki/C._Raveendranath
# Running for article /wiki/T._N._Seema
# Running for article /wiki/K._B._Unnithan
# Running for article /wiki/Joseph_Vadakkan
# Running for article /wiki/Chunkath_Joseph_Varkey
# Running for article /wiki/M._P._Vincent
# Running for article /wiki/K._Krishnan_Warrier
# Running for article /wiki/List_of_politicians_of_Kerala
# Running for article /wiki/Political_families_of_Kerala
# Running for article /wiki/A._P._Abdullakutty
# Running for article /wiki/K._M._Abraham
# Running for article /wiki/K._Achuthan
# Running for article /wiki/V._S._Achuthanandan
# Running for article /wiki/K._G._Adiyodi
# Running for article /wiki/Alexander_Parambithara
# Running for article /wiki/A._M._Ariff
# Running for article /wiki/A._V._Aryan
# Running for article /wiki/C._K._Asha
# Running for article /wiki/K._Babu
# Running for article /wiki/Gowri_Lakshmi_Bayi
# Running for article /wiki/M._Chandran
# Running for article /wiki/K._K._Chettur
# Running for article /wiki/K._B._Ganesh_Kumar
# Running for article /wiki/C._S._Gangadharan
# Running for article /wiki/K._R._Gouri_Amma
# Running for article /wiki/M._K._A._Hameed
# Running for article /wiki/Innocent_(actor)
# Running for article /wiki/Anoop_Jacob
# Running for article /wiki/E._John_Jacob
# Running for article /wiki/T._M._Jacob
# Running for article /wiki/Jagadish_Kumar
# Running for article /wiki/Shibu_Baby_John
# Running for article /wiki/Sajeev_Joseph
# Running for article /wiki/P._J._Joy
# Running for article /wiki/K.T._Achuthan
# Running for article /wiki/V._C._Kabeer
# Running for article /wiki/M._K._Kannan
# Running for article /wiki/K._Karunakaran
# Running for article /wiki/Ninan_Koshy
# Running for article /wiki/C._H._Mohammed_Koya
# Running for article /wiki/C._Madhavan_Nair
# Running for article /wiki/Jose_K._Mani
# Running for article /wiki/K._M._Mani
# Running for article /wiki/K._G._Marar
# Running for article /wiki/V._M._Ummer_Master
# Running for article /wiki/Ranjan_Mathai
# Running for article /wiki/C._P._Mathew
# Running for article /wiki/K._K._Mathew
# Running for article /wiki/M._P._M._Menon
# Running for article /wiki/P._Chandra_Mohan
# Running for article /wiki/K._P._Mohanan
# Running for article /wiki/A._C._Moideen
# Running for article /wiki/V._Muraleedharan
# Running for article /wiki/N._Sundaran_Nadar
# Running for article /wiki/V._Parameswaran_Nayar
# Running for article /wiki/P._Parameswaran
# Running for article /wiki/Murali_Perunelly
# Running for article /wiki/P._S._Sreedharan_Pillai
# Running for article /wiki/R._Balakrishna_Pillai
# Running for article /wiki/K._D._Prasenan
# Running for article /wiki/U._Prathibha
# Running for article /wiki/Pukkoya_Tangal
# Running for article /wiki/O._Rajagopal
# Running for article /wiki/V._K._Rajan
# Running for article /wiki/Kummanam_Rajasekharan
# Running for article /wiki/K._K._Ramachandran_Master
# Running for article /wiki/N_Ramakrishnan
# Running for article /wiki/P._Ravindran
# Running for article /wiki/P._A._Mohammed_Riyas
# Running for article /wiki/S._Kumaran
# Running for article /wiki/P._Santhosh_Kumar
# Running for article /wiki/V._P._Sanu
# Running for article /wiki/V._Sivadasan
# Running for article /wiki/Punnala_Sreekumar
# Running for article /wiki/Girija_Surendran
# Running for article /wiki/K._Surendran_(politician)
# Running for article /wiki/Shashi_Tharoor
# Running for article /wiki/Jose_Thettayil
# Running for article /wiki/R._Velayudhan
# Running for article /wiki/M._Vijin
# Running for article /wiki/Template_talk:Kerala
# Running for article /wiki/States_and_territories_of_India
# Running for article /wiki/Kerala
# Running for article /wiki/List_of_state_and_union_territory_capitals_in_India
# Running for article /wiki/Thiruvananthapuram
# Running for article /wiki/List_of_districts_in_Kerala
# Running for article /wiki/Thiruvananthapuram_district
# Running for article /wiki/Kollam_district
# Running for article /wiki/Pathanamthitta_district
# Running for article /wiki/Alappuzha_district
# Running for article /wiki/Kottayam_district
# Running for article /wiki/Idukki_district
# Running for article /wiki/Ernakulam_district
# Running for article /wiki/Thrissur_district
# Running for article /wiki/Palakkad_district
# Running for article /wiki/Malappuram_district
# Running for article /wiki/Kozhikode_district
# Running for article /wiki/Wayanad_district
# Running for article /wiki/Kannur_district
# Running for article /wiki/Kasaragod_district
# Running for article /wiki/Arts_of_Kerala
# Running for article /wiki/Culture_of_Kerala
# Running for article /wiki/Demographics_of_Kerala
# Running for article /wiki/Economy_of_Kerala
# Running for article /wiki/Education_in_Kerala
# Running for article /wiki/Malayalam_cinema
# Running for article /wiki/Geography_of_Kerala
# Running for article /wiki/Roads_in_Kerala
# Running for article /wiki/Ports_in_Kerala
# Running for article /wiki/History_of_Kerala
# Running for article /wiki/Wildlife_of_Kerala
# Running for article /wiki/Government_of_Kerala
# Running for article /wiki/Tourism_in_Kerala
# Running for article /wiki/Sports_in_Kerala
# Running for article /wiki/Great_hornbill
# Running for article /wiki/Indian_elephant
# Running for article /wiki/Coconut
# Running for article /wiki/Cassia_fistula
# Running for article /wiki/Karimeen
# Running for article /wiki/Jackfruit
# Running for article /wiki/Papilio_buddha
# Running for article /wiki/Taluks_of_Kerala
# Running for article /wiki/Adoor
# Running for article /wiki/Alathur
# Running for article /wiki/Aluva
# Running for article /wiki/Ambalappuzha
# Running for article /wiki/Chalakudy
# Running for article /wiki/Changanassery
# Running for article /wiki/Chavakkad
# Running for article /wiki/Chengannur
# Running for article /wiki/Cherthala
# Running for article /wiki/Chirayinkeezhu_taluk
# Running for article /wiki/Chittur-Thathamangalam
# Running for article /wiki/Devikulam
# Running for article /wiki/Eranad_Taluk
# Running for article /wiki/Hosdurg_taluk
# Running for article /wiki/Idukki
# Running for article /wiki/Iritty_taluk
# Running for article /wiki/Kanayannur
# Running for article /wiki/Kanjirappally
# Running for article /wiki/Kannur_taluk
# Running for article /wiki/Karthikappally
# Running for article /wiki/Karunagappalli
# Running for article /wiki/Kasaragod_taluk
# Running for article /wiki/Kattakada
# Running for article /wiki/Kochi
# Running for article /wiki/Kodungallur
# Running for article /wiki/Kollam_Taluk
# Running for article /wiki/Kondotty_Taluk
# Running for article /wiki/Konni,_Kerala
# Running for article /wiki/Kothamangalam
# Running for article /wiki/Kottarakkara
# Running for article /wiki/Kottayam
# Running for article /wiki/Koyilandy
# Running for article /wiki/Kozhencherry
# Running for article /wiki/Kozhikode
# Running for article /wiki/Kunnamkulam
# Running for article /wiki/Kunnathunad
# Running for article /wiki/Kunnathur_(Kerala)
# Running for article /wiki/Kuttanad
# Running for article /wiki/Mallapally
# Running for article /wiki/Mananthavady
# Running for article /wiki/Manjeshwaram_Taluk
# Running for article /wiki/Mannarkkad
# Running for article /wiki/Mavelikkara
# Running for article /wiki/Meenachil
# Running for article /wiki/Mukundapuram_Taluk
# Running for article /wiki/Muvattupuzha
# Running for article /wiki/Nedumangad_taluk
# Running for article /wiki/Neyyattinkara_taluk
# Running for article /wiki/Nilambur
# Running for article /wiki/Paravur_Taluk
# Running for article /wiki/Ottapalam
# Running for article /wiki/Palakkad
# Running for article /wiki/Pathanapuram
# Running for article /wiki/Pattambi
# Running for article /wiki/Payyanur_Taluk
# Running for article /wiki/Peermade
# Running for article /wiki/Perinthalmanna_taluk
# Running for article /wiki/Ponnani_taluk
# Running for article /wiki/Punalur
# Running for article /wiki/Ranni,_Kerala
# Running for article /wiki/Sultan_Bathery
# Running for article /wiki/Taliparamba_taluk
# Running for article /wiki/Thalapilly
# Running for article /wiki/Thalassery
# Running for article /wiki/Thamarassery
# Running for article /wiki/Thiruvalla
# Running for article /wiki/Thiruvananthapuram_Taluk
# Running for article /wiki/Thodupuzha
# Running for article /wiki/Thrissur
# Running for article /wiki/Tirur_Taluk
# Running for article /wiki/Tirurangadi_Taluk_Office
# Running for article /wiki/Udumbanchola
# Running for article /wiki/Vaikom
# Running for article /wiki/Varkala
# Running for article /wiki/Vatakara
# Running for article /wiki/Vellarikundu_Taluk
# Running for article /wiki/Vythiri
# Running for article /wiki/Municipal_Corporations_in_Kerala
# Running for article /wiki/Thiruvananthapuram_Municipal_Corporation
# Running for article /wiki/Kozhikode_Municipal_Corporation
# Running for article /wiki/Kochi_Municipal_Corporation
# Running for article /wiki/Kollam_Municipal_Corporation
# Running for article /wiki/Thrissur_Municipal_Corporation
# Running for article /wiki/Kannur_Municipal_Corporation
# Running for article /wiki/Municipalities_of_Kerala
# Running for article /wiki/Adoor
# Running for article /wiki/Anthoor
# Running for article /wiki/Alappuzha
# Running for article /wiki/Aluva
# Running for article /wiki/Angamaly
# Running for article /wiki/Attingal
# Running for article /wiki/Chalakudy
# Running for article /wiki/Changanassery
# Running for article /wiki/Chavakkad
# Running for article /wiki/Chengannur
# Running for article /wiki/Cherthala
# Running for article /wiki/Chittur-Thathamangalam
# Running for article /wiki/Eloor
# Running for article /wiki/Guruvayur
# Running for article /wiki/Irinjalakuda
# Running for article /wiki/Iritty
# Running for article /wiki/Kalamassery
# Running for article /wiki/Kalpetta
# Running for article /wiki/Kanhangad
# Running for article /wiki/Karunagappalli
# Running for article /wiki/Kasaragod
# Running for article /wiki/Kayamkulam
# Running for article /wiki/Kodungallur
# Running for article /wiki/Kondotty
# Running for article /wiki/Kuthuparamba
# Running for article /wiki/Kothamangalam
# Running for article /wiki/Kottakkal
# Running for article /wiki/Kottarakkara
# Running for article /wiki/Kottayam
# Running for article /wiki/Koyilandy
# Running for article /wiki/Kunnamkulam
# Running for article /wiki/Malappuram
# Running for article /wiki/Manjeri
# Running for article /wiki/Maradu
# Running for article /wiki/Mattanur
# Running for article /wiki/Mavelikkara
# Running for article /wiki/Muvattupuzha
# Running for article /wiki/Nedumangad
# Running for article /wiki/Neyyattinkara
# Running for article /wiki/Nilambur
# Running for article /wiki/Nileshwaram
# Running for article /wiki/North_Paravur
# Running for article /wiki/Ottapalam
# Running for article /wiki/Pala,_Kerala
# Running for article /wiki/Palakkad
# Running for article /wiki/Panoor
# Running for article /wiki/Parappanangadi
# Running for article /wiki/Paravur,_Kollam
# Running for article /wiki/Pathanamthitta
# Running for article /wiki/Payyanur
# Running for article /wiki/Perinthalmanna
# Running for article /wiki/Perumbavoor
# Running for article /wiki/Ponnani
# Running for article /wiki/Punalur
# Running for article /wiki/Shoranur
# Running for article /wiki/Sreekandapuram
# Running for article /wiki/Tanur,_Malappuram
# Running for article /wiki/Thalassery
# Running for article /wiki/Taliparamba
# Running for article /wiki/Thiruvalla
# Running for article /wiki/Thodupuzha
# Running for article /wiki/Thrikkakkara
# Running for article /wiki/Thrippunithura
# Running for article /wiki/Tirur
# Running for article /wiki/Tirurangadi
# Running for article /wiki/Valanchery
# Running for article /wiki/Vatakara
# Running for article /wiki/Vaikom
# Running for article /wiki/Varkala
# Running for article /wiki/Edappal
# Running for article /wiki/Tavanur
# Running for article /wiki/Angadipuram
# Running for article /wiki/Mankada
# Running for article /wiki/Kuttippuram
# Running for article /wiki/Karipur
# Running for article /wiki/Areekode
# Running for article /wiki/Wandoor
# Running for article /wiki/Vengara,_Malappuram_district
# Running for article /wiki/Vallikkunnu
# Running for article /wiki/Olavanna
# Running for article /wiki/Kunnamangalam
# Running for article /wiki/Thamarassery
# Running for article /wiki/Thiruvambady
# Running for article /wiki/Kodencheri
# Running for article /wiki/Balussery
# Running for article /wiki/Perambra
# Running for article /wiki/Nadapuram
# Running for article /wiki/Kuttiady
# Running for article /wiki/Lakkidi,_Wayanad
# Running for article /wiki/Vythiri
# Running for article /wiki/Chundale
# Running for article /wiki/Meppadi
# Running for article /wiki/Kottappadi
# Running for article /wiki/Muttil,_Kalpetta
# Running for article /wiki/Padinharethara
# Running for article /wiki/Meenangadi
# Running for article /wiki/Panamaram
# Running for article /wiki/Pulpally
# Running for article /wiki/Peravoor
# Running for article /wiki/Dharmadom
# Running for article /wiki/Anjarakkandy
# Running for article /wiki/Muzhappilangad
# Running for article /wiki/Azhikode_and_Azhikkal
# Running for article /wiki/Cherukunnu
# Running for article /wiki/Pappinisseri
# Running for article /wiki/Kalliasseri
# Running for article /wiki/Irikkur
# Running for article /wiki/Alakode,_Kannur_district
# Running for article /wiki/Trikaripur
# Running for article /wiki/Cheruvathur
# Running for article /wiki/Bekal
# Running for article /wiki/Udma
# Running for article /wiki/Vellarikundu
# Running for article /wiki/Parappa_(village)
# Running for article /wiki/Karadka
# Running for article /wiki/Kumbla
# Running for article /wiki/Mangalpady
# Running for article /wiki/Uppala
# Running for article /wiki/Manjeshwar
# Running for article /wiki/Peermade
# Running for article /wiki/Vandiperiyar
# Running for article /wiki/Kumily
# Running for article /wiki/Rajakkad
# Running for article /wiki/Munnar
# Running for article /wiki/Devikulam
# Running for article /wiki/Adimali
# Running for article /wiki/Kolenchery
# Running for article /wiki/Puthencruz
# Running for article /wiki/Kunnathunad
# Running for article /wiki/Kalady
# Running for article /wiki/Malayattoor
# Running for article /wiki/Chottanikkara
# Running for article /wiki/Udayamperoor
# Running for article /wiki/Varappuzha
# Running for article /wiki/Sreemoolanagaram
# Running for article /wiki/Nedumbassery
# Running for article /wiki/Mala,_Kerala
# Running for article /wiki/Kodakara
# Running for article /wiki/Puthukkad
# Running for article /wiki/Manaloor
# Running for article /wiki/Pavaratty
# Running for article /wiki/Chelakkara
# Running for article /wiki/Vadakkencherry
# Running for article /wiki/Alathur
# Running for article /wiki/Nemmara
# Running for article /wiki/Puthunagaram
# Running for article /wiki/Malampuzha
# Running for article /wiki/Sreekrishnapuram,_Palakkad
# Running for article /wiki/Lakkidi,_Palakkad
# Running for article /wiki/Thrithala
# Running for article /wiki/Parassala
# Running for article /wiki/Balaramapuram
# Running for article /wiki/Kattakada
# Running for article /wiki/Chirayinkeezhu
# Running for article /wiki/Kilimanoor
# Running for article /wiki/Parippally
# Running for article /wiki/Chathannoor
# Running for article /wiki/Kottiyam
# Running for article /wiki/Kundara
# Running for article /wiki/Neendakara
# Running for article /wiki/Chavara
# Running for article /wiki/Oachira
# Running for article /wiki/Sasthamkotta
# Running for article /wiki/Kunnathur_(Kerala)
# Running for article /wiki/Anchal
# Running for article /wiki/Kadakkal
# Running for article /wiki/Pathanapuram
# Running for article /wiki/Thenmala
# Running for article /wiki/Kulathupuzha
# Running for article /wiki/Kozhencherry
# Running for article /wiki/Konni,_Kerala
# Running for article /wiki/Ranni,_Kerala
# Running for article /wiki/Mallapally
# Running for article /wiki/Kumbanad
# Running for article /wiki/Aranmula
# Running for article /wiki/Kulanada
# Running for article /wiki/Omallur
# Running for article /wiki/Vadasserikara
# Running for article /wiki/Parumala
# Running for article /wiki/Mannar,_Alappuzha
# Running for article /wiki/Charummoodu
# Running for article /wiki/Ambalappuzha
# Running for article /wiki/Mararikulam
# Running for article /wiki/Aroor
# Running for article /wiki/Kanjirappally
# Running for article /wiki/Erumely
# Running for article /wiki/Mundakayam
# Running for article /wiki/Vazhoor
# Running for article /wiki/Karukachal
# Running for article /wiki/Pampady
# Running for article /wiki/Puthuppally,_Kottayam
# Running for article /wiki/Kuravilangad
# Running for article /wiki/Uzhavoor
# Running for article /wiki/Thalayolaparambu
# Running for article /wiki/Kaduthuruthy
# Running for article /wiki/Kerala#Subdivisions
# Running for article /wiki/Kolathunadu
# Running for article /wiki/Zamorin_of_Calicut
# Running for article /wiki/Malabar_District
# Running for article /wiki/North_Malabar
# Running for article /wiki/South_Malabar
# Running for article /wiki/Kingdom_of_Cochin
# Running for article /wiki/Venad
# Running for article /wiki/Travancore
# Running for article /wiki/Travancore-Cochin
# Running for article /wiki/India
# Running for article /wiki/Template_talk:Kerala
# Running for article /wiki/States_and_territories_of_India
# Running for article /wiki/Kerala
# Running for article /wiki/List_of_state_and_union_territory_capitals_in_India
# Running for article /wiki/Thiruvananthapuram
# Running for article /wiki/List_of_districts_in_Kerala
# Running for article /wiki/Thiruvananthapuram_district
# Running for article /wiki/Kollam_district
# Running for article /wiki/Pathanamthitta_district
# Running for article /wiki/Alappuzha_district
# Running for article /wiki/Kottayam_district
# Running for article /wiki/Idukki_district
# Running for article /wiki/Ernakulam_district
# Running for article /wiki/Thrissur_district
# Running for article /wiki/Palakkad_district
# Running for article /wiki/Malappuram_district
# Running for article /wiki/Kozhikode_district
# Running for article /wiki/Wayanad_district
# Running for article /wiki/Kannur_district
# Running for article /wiki/Kasaragod_district
# Running for article /wiki/Arts_of_Kerala
# Running for article /wiki/Culture_of_Kerala
# Running for article /wiki/Demographics_of_Kerala
# Running for article /wiki/Economy_of_Kerala
# Running for article /wiki/Education_in_Kerala
# Running for article /wiki/Malayalam_cinema
# Running for article /wiki/Geography_of_Kerala
# Running for article /wiki/Roads_in_Kerala
# Running for article /wiki/Ports_in_Kerala
# Running for article /wiki/History_of_Kerala
# Running for article /wiki/Wildlife_of_Kerala
# Running for article /wiki/Government_of_Kerala
# Running for article /wiki/Tourism_in_Kerala
# Running for article /wiki/Sports_in_Kerala
# Running for article /wiki/Great_hornbill
# Running for article /wiki/Indian_elephant
# Running for article /wiki/Coconut
# Running for article /wiki/Cassia_fistula
# Running for article /wiki/Karimeen
# Running for article /wiki/Jackfruit
# Running for article /wiki/Papilio_buddha
# Running for article /wiki/Taluks_of_Kerala
# Running for article /wiki/Adoor
# Running for article /wiki/Alathur
# Running for article /wiki/Aluva
# Running for article /wiki/Ambalappuzha
# Running for article /wiki/Chalakudy
# Running for article /wiki/Changanassery
# Running for article /wiki/Chavakkad
# Running for article /wiki/Chengannur
# Running for article /wiki/Cherthala
# Running for article /wiki/Chirayinkeezhu_taluk
# Running for article /wiki/Chittur-Thathamangalam
# Running for article /wiki/Devikulam
# Running for article /wiki/Eranad_Taluk
# Running for article /wiki/Hosdurg_taluk
# Running for article /wiki/Idukki
# Running for article /wiki/Iritty_taluk
# Running for article /wiki/Kanayannur
# Running for article /wiki/Kanjirappally
# Running for article /wiki/Kannur_taluk
# Running for article /wiki/Karthikappally
# Running for article /wiki/Karunagappalli
# Running for article /wiki/Kasaragod_taluk
# Running for article /wiki/Kattakada
# Running for article /wiki/Kochi
# Running for article /wiki/Kodungallur
# Running for article /wiki/Kollam_Taluk
# Running for article /wiki/Kondotty_Taluk
# Running for article /wiki/Konni,_Kerala
# Running for article /wiki/Kothamangalam
# Running for article /wiki/Kottarakkara
# Running for article /wiki/Kottayam
# Running for article /wiki/Koyilandy
# Running for article /wiki/Kozhencherry
# Running for article /wiki/Kozhikode
# Running for article /wiki/Kunnamkulam
# Running for article /wiki/Kunnathunad
# Running for article /wiki/Kunnathur_(Kerala)
# Running for article /wiki/Kuttanad
# Running for article /wiki/Mallapally
# Running for article /wiki/Mananthavady
# Running for article /wiki/Manjeshwaram_Taluk
# Running for article /wiki/Mannarkkad
# Running for article /wiki/Mavelikkara
# Running for article /wiki/Meenachil
# Running for article /wiki/Mukundapuram_Taluk
# Running for article /wiki/Muvattupuzha
# Running for article /wiki/Nedumangad_taluk
# Running for article /wiki/Neyyattinkara_taluk
# Running for article /wiki/Nilambur
# Running for article /wiki/Paravur_Taluk
# Running for article /wiki/Ottapalam
# Running for article /wiki/Palakkad
# Running for article /wiki/Pathanapuram
# Running for article /wiki/Pattambi
# Running for article /wiki/Payyanur_Taluk
# Running for article /wiki/Peermade
# Running for article /wiki/Perinthalmanna_taluk
# Running for article /wiki/Ponnani_taluk
# Running for article /wiki/Punalur
# Running for article /wiki/Ranni,_Kerala
# Running for article /wiki/Sultan_Bathery
# Running for article /wiki/Taliparamba_taluk
# Running for article /wiki/Thalapilly
# Running for article /wiki/Thalassery
# Running for article /wiki/Thamarassery
# Running for article /wiki/Thiruvalla
# Running for article /wiki/Thiruvananthapuram_Taluk
# Running for article /wiki/Thodupuzha
# Running for article /wiki/Thrissur
# Running for article /wiki/Tirur_Taluk
# Running for article /wiki/Tirurangadi_Taluk_Office
# Running for article /wiki/Udumbanchola
# Running for article /wiki/Vaikom
# Running for article /wiki/Varkala
# Running for article /wiki/Vatakara
# Running for article /wiki/Vellarikundu_Taluk
# Running for article /wiki/Vythiri
# Running for article /wiki/Municipal_Corporations_in_Kerala
# Running for article /wiki/Thiruvananthapuram_Municipal_Corporation
# Running for article /wiki/Kozhikode_Municipal_Corporation
# Running for article /wiki/Kochi_Municipal_Corporation
# Running for article /wiki/Kollam_Municipal_Corporation
# Running for article /wiki/Thrissur_Municipal_Corporation
# Running for article /wiki/Kannur_Municipal_Corporation
# Running for article /wiki/Municipalities_of_Kerala
# Running for article /wiki/Adoor
# Running for article /wiki/Anthoor
# Running for article /wiki/Alappuzha
# Running for article /wiki/Aluva
# Running for article /wiki/Angamaly
# Running for article /wiki/Attingal
# Running for article /wiki/Chalakudy
# Running for article /wiki/Changanassery
# Running for article /wiki/Chavakkad
# Running for article /wiki/Chengannur
# Running for article /wiki/Cherthala
# Running for article /wiki/Chittur-Thathamangalam
# Running for article /wiki/Eloor
# Running for article /wiki/Guruvayur
# Running for article /wiki/Irinjalakuda
# Running for article /wiki/Iritty
# Running for article /wiki/Kalamassery
# Running for article /wiki/Kalpetta
# Running for article /wiki/Kanhangad
# Running for article /wiki/Karunagappalli
# Running for article /wiki/Kasaragod
# Running for article /wiki/Kayamkulam
# Running for article /wiki/Kodungallur
# Running for article /wiki/Kondotty
# Running for article /wiki/Kuthuparamba
# Running for article /wiki/Kothamangalam
# Running for article /wiki/Kottakkal
# Running for article /wiki/Kottarakkara
# Running for article /wiki/Kottayam
# Running for article /wiki/Koyilandy
# Running for article /wiki/Kunnamkulam
# Running for article /wiki/Malappuram
# Running for article /wiki/Manjeri
# Running for article /wiki/Maradu
# Running for article /wiki/Mattanur
# Running for article /wiki/Mavelikkara
# Running for article /wiki/Muvattupuzha
# Running for article /wiki/Nedumangad
# Running for article /wiki/Neyyattinkara
# Running for article /wiki/Nilambur
# Running for article /wiki/Nileshwaram
# Running for article /wiki/North_Paravur
# Running for article /wiki/Ottapalam
# Running for article /wiki/Pala,_Kerala
# Running for article /wiki/Palakkad
# Running for article /wiki/Panoor
# Running for article /wiki/Parappanangadi
# Running for article /wiki/Paravur,_Kollam
# Running for article /wiki/Pathanamthitta
# Running for article /wiki/Payyanur
# Running for article /wiki/Perinthalmanna
# Running for article /wiki/Perumbavoor
# Running for article /wiki/Ponnani
# Running for article /wiki/Punalur
# Running for article /wiki/Shoranur
# Running for article /wiki/Sreekandapuram
# Running for article /wiki/Tanur,_Malappuram
# Running for article /wiki/Thalassery
# Running for article /wiki/Taliparamba
# Running for article /wiki/Thiruvalla
# Running for article /wiki/Thodupuzha
# Running for article /wiki/Thrikkakkara
# Running for article /wiki/Thrippunithura
# Running for article /wiki/Tirur
# Running for article /wiki/Tirurangadi
# Running for article /wiki/Valanchery
# Running for article /wiki/Vatakara
# Running for article /wiki/Vaikom
# Running for article /wiki/Varkala
# Running for article /wiki/Edappal
# Running for article /wiki/Tavanur
# Running for article /wiki/Angadipuram
# Running for article /wiki/Mankada
# Running for article /wiki/Kuttippuram
# Running for article /wiki/Karipur
# Running for article /wiki/Areekode
# Running for article /wiki/Wandoor
# Running for article /wiki/Vengara,_Malappuram_district
# Running for article /wiki/Vallikkunnu
# Running for article /wiki/Olavanna
# Running for article /wiki/Kunnamangalam
# Running for article /wiki/Thamarassery
# Running for article /wiki/Thiruvambady
# Running for article /wiki/Kodencheri
# Running for article /wiki/Balussery
# Running for article /wiki/Perambra
# Running for article /wiki/Nadapuram
# Running for article /wiki/Kuttiady
# Running for article /wiki/Lakkidi,_Wayanad
# Running for article /wiki/Vythiri
# Running for article /wiki/Chundale
# Running for article /wiki/Meppadi
# Running for article /wiki/Kottappadi
# Running for article /wiki/Muttil,_Kalpetta
# Running for article /wiki/Padinharethara
# Running for article /wiki/Meenangadi
# Running for article /wiki/Panamaram
# Running for article /wiki/Pulpally
# Running for article /wiki/Peravoor
# Running for article /wiki/Dharmadom
# Running for article /wiki/Anjarakkandy
# Running for article /wiki/Muzhappilangad
# Running for article /wiki/Azhikode_and_Azhikkal
# Running for article /wiki/Cherukunnu
# Running for article /wiki/Pappinisseri
# Running for article /wiki/Kalliasseri
# Running for article /wiki/Irikkur
# Running for article /wiki/Alakode,_Kannur_district
# Running for article /wiki/Trikaripur
# Running for article /wiki/Cheruvathur
# Running for article /wiki/Bekal
# Running for article /wiki/Udma
# Running for article /wiki/Vellarikundu
# Running for article /wiki/Parappa_(village)
# Running for article /wiki/Karadka
# Running for article /wiki/Kumbla
# Running for article /wiki/Mangalpady
# Running for article /wiki/Uppala
# Running for article /wiki/Manjeshwar
# Running for article /wiki/Peermade
# Running for article /wiki/Vandiperiyar
# Running for article /wiki/Kumily
# Running for article /wiki/Rajakkad
# Running for article /wiki/Munnar
# Running for article /wiki/Devikulam
# Running for article /wiki/Adimali
# Running for article /wiki/Kolenchery
# Running for article /wiki/Puthencruz
# Running for article /wiki/Kunnathunad
# Running for article /wiki/Kalady
# Running for article /wiki/Malayattoor
# Running for article /wiki/Chottanikkara
# Running for article /wiki/Udayamperoor
# Running for article /wiki/Varappuzha
# Running for article /wiki/Sreemoolanagaram
# Running for article /wiki/Nedumbassery
# Running for article /wiki/Mala,_Kerala
# Running for article /wiki/Kodakara
# Running for article /wiki/Puthukkad
# Running for article /wiki/Manaloor
# Running for article /wiki/Pavaratty
# Running for article /wiki/Chelakkara
# Running for article /wiki/Vadakkencherry
# Running for article /wiki/Alathur
# Running for article /wiki/Nemmara
# Running for article /wiki/Puthunagaram
# Running for article /wiki/Malampuzha
# Running for article /wiki/Sreekrishnapuram,_Palakkad
# Running for article /wiki/Lakkidi,_Palakkad
# Running for article /wiki/Thrithala
# Running for article /wiki/Parassala
# Running for article /wiki/Balaramapuram
# Running for article /wiki/Kattakada
# Running for article /wiki/Chirayinkeezhu
# Running for article /wiki/Kilimanoor
# Running for article /wiki/Parippally
# Running for article /wiki/Chathannoor
# Running for article /wiki/Kottiyam
# Running for article /wiki/Kundara
# Running for article /wiki/Neendakara
# Running for article /wiki/Chavara
# ...
# Running for article /wiki/Mauli_Chandra_Sharma
# Running for article /wiki/Master_Azad_Singh
# Running for article /wiki/R._P._Singh_(politician)
# Running for article /wiki/Satbir_Singh_(politician)
# Running for article /wiki/Vani_Tripathi
# Running for article /wiki/Ashok_Kumar_Walia
# Running for article /wiki/Brahm_Yadav
# Running for article /wiki/Yogendra_Yadav
# Running for article /wiki/Political_families_of_Haryana
# Running for article /wiki/Agnivesh
# Running for article /wiki/Naseem_Ahmed
# Running for article /wiki/Renu_Bala
# Running for article /wiki/Ram_Prakash_Chaudhary
# Running for article /wiki/Anirudh_Chaudhry
# Running for article /wiki/Ravinder_Singh_Dhull
# Running for article /wiki/Naresh_Kamboj
# Running for article /wiki/Rampal_Majra
# Running for article /wiki/Anil_Mehta_(politician)
# Running for article /wiki/Aman_Kumar_Nagra
# Running for article /wiki/K._R._Punia
# Running for article /wiki/Chiranji_Lal_Sharma
# Running for article /wiki/Balkaur_Singh
# Running for article /wiki/Chaudhary_Randhir_Singh
# Running for article /wiki/Surinder_Singh_(commando)
# Running for article /wiki/Nihal_Singh_Takshak
# Running for article /wiki/Ram_Chander_Bainda
# Running for article /wiki/Avtar_Singh_Bhadana
# Running for article /wiki/Krishan_Pal_Gurjar
# Running for article /wiki/Bhajan_Lal
# Running for article /wiki/India
# Running for article /wiki/Ram_Chander_Bainda
# Running for article /wiki/Avtar_Singh_Bhadana
# Running for article /wiki/Krishan_Pal_Gurjar
# Running for article /wiki/Bhajan_Lal
# Running for article /wiki/Abdul_Aziz_(Indian_politician)
# Running for article /wiki/Abdul_Batin_Khandakar
# Running for article /wiki/Abu_Saleh_Najmuddin
# Running for article /wiki/Jahan_Uddin_Ahmed
# Running for article /wiki/Amjad_Ali_(Assam_politician)
# Running for article /wiki/Mahmud_Ali_(statesman)
# Running for article /wiki/Ramesh_Chandra_Barooah
# Running for article /wiki/Siva_Prasad_Barooah
# Running for article /wiki/Kanaklal_Barua
# Running for article /wiki/Dipankar_Bhattacharya
# Running for article /wiki/Prodyut_Bora
# Running for article /wiki/Pramod_Boro
# Running for article /wiki/Bineswar_Brahma
# Running for article /wiki/Dipayan_Chakraborty
# Running for article /wiki/Abdul_Jalil_Choudhury
# Running for article /wiki/Moinul_Hoque_Choudhury
# Running for article /wiki/Guneswar_Das
# Running for article /wiki/Jyoti_Prasad_Das
# Running for article /wiki/Krishna_Das_(politician)
# Running for article /wiki/Biren_Deka
# Running for article /wiki/Nilamani_Sen_Deka
# Running for article /wiki/Dinesh_Prasad_Goala
# Running for article /wiki/Khorsing_Engti
# Running for article /wiki/Alok_Kumar_Ghosh
# Running for article /wiki/Nripen_Goswami
# Running for article /wiki/Padma_Hazarika
# Running for article /wiki/Ashraful_Hussain
# Running for article /wiki/Aminul_Islam_(Indian_politician,_born_1975)
# Running for article /wiki/Karim_Uddin_Barbhuiya
# Running for article /wiki/Abdul_Khaleque_(Assamese_politician)
# Running for article /wiki/Ali_Haider_Khan
# Running for article /wiki/Liladhar_Kotoki
# Running for article /wiki/Rupam_Kurmi
# Running for article /wiki/Gobinda_Chandra_Langthasa
# Running for article /wiki/Zakir_Hussain_Laskar
# Running for article /wiki/Girindra_Mallik
# Running for article /wiki/Pabitra_Margherita
# Running for article /wiki/Abdul_Muhib_Mazumder
# Running for article /wiki/Bishnuram_Medhi
# Running for article /wiki/Hagrama_Mohilary
# Running for article /wiki/Atuwa_Munda
# Running for article /wiki/Nagen_Neog
# Running for article /wiki/Kalpana_Patowary
# Running for article /wiki/Ranoj_Pegu
# Running for article /wiki/Phanidhar_Talukdar
# Running for article /wiki/Tarun_Ram_Phukan
# Running for article /wiki/Pradip_Sarkar_(politician)
# Running for article /wiki/Golok_Rajbanshi
# Running for article /wiki/Rajdeep_Goala
# Running for article /wiki/Gautam_Roy
# Running for article /wiki/Baneswar_Saikia
# Running for article /wiki/Muhi_Ram_Saikia
# Running for article /wiki/Samsul_Huda
# Running for article /wiki/Debomoy_Sanyal
# Running for article /wiki/Sarat_Barkotoky
# Running for article /wiki/Chandan_Kumar_Sarkar
# Running for article /wiki/Birendra_Prasad_Baishya
# Running for article /wiki/Bhumidhar_Barman
# Running for article /wiki/Dipankar_Bhattacharya
# Running for article /wiki/Siddhartha_Bhattacharya
# Running for article /wiki/Robin_Bordoloi
# Running for article /wiki/Harishankar_Brahma
# Running for article /wiki/Nandita_Das_(politician)
# Running for article /wiki/Ajoy_Kumar_Dutta
# Running for article /wiki/Tarun_Gogoi
# Running for article /wiki/Suman_Haripriya
# Running for article /wiki/Ramendra_Narayan_Kalita
# Running for article /wiki/Devanand_Konwar
# Running for article /wiki/Ajanta_Neog
# Running for article /wiki/Tarun_Ram_Phukan
# Running for article /wiki/Rekibuddin_Ahmed
# Running for article /wiki/Biraj_Kumar_Sarma
# Running for article /wiki/Himanta_Biswa_Sarma
# Running for article /wiki/Ashok_Singhal_(politician)
# Running for article /wiki/India
# Running for article /wiki/Birendra_Prasad_Baishya
# Running for article /wiki/Bhumidhar_Barman
# Running for article /wiki/Dipankar_Bhattacharya
# Running for article /wiki/Siddhartha_Bhattacharya
# Running for article /wiki/Robin_Bordoloi
# Running for article /wiki/Harishankar_Brahma
# Running for article /wiki/Nandita_Das_(politician)
# Running for article /wiki/Ajoy_Kumar_Dutta
# Running for article /wiki/Tarun_Gogoi
# Running for article /wiki/Suman_Haripriya
# Running for article /wiki/Ramendra_Narayan_Kalita
# Running for article /wiki/Devanand_Konwar
# Running for article /wiki/Ajanta_Neog
# Running for article /wiki/Tarun_Ram_Phukan
# Running for article /wiki/Rekibuddin_Ahmed
# Running for article /wiki/Biraj_Kumar_Sarma
# Running for article /wiki/Himanta_Biswa_Sarma
# Running for article /wiki/Ashok_Singhal_(politician)
# Running for article /wiki/Shamraj_Bhalerao
# Running for article /wiki/Gopal_Rao_Ekbote
# Running for article /wiki/Goka_Ramalingam
# Running for article /wiki/Kashinath_Rao_Vaidya
# Running for article /wiki/G._S._Melkote
# Running for article /wiki/Nawab_Alam_Yar_Jung_Bahadur
# Running for article /wiki/Mukundrao_Pedgaonkar
# Running for article /wiki/Kishen_Pershad
# Running for article /wiki/M._K._Vellodi
# Running for article /wiki/Mayor_of_Hyderabad,_India
# Running for article /wiki/Rani_Kumudini_Devi
# Running for article /wiki/Mohammad_Majid_Hussain
# Running for article /wiki/List_of_mayors_of_Hyderabad
# Running for article /wiki/Krishna_Swamy_Mudiraj
# Running for article /wiki/Laxminarayana_Mudiraj
# Running for article /wiki/Bonthu_Rammohan
# Running for article /wiki/Madapati_Hanumantha_Rao
# Running for article /wiki/Banda_Karthika_Reddy
# Running for article /wiki/Sarojini_Pulla_Reddy
# Running for article /wiki/Gadwal_Vijayalakshmi
# Running for article /wiki/T._Anjaiah
# Running for article /wiki/Eshwari_Bai
# Running for article /wiki/Dipika_Damerla
# Running for article /wiki/Bandaru_Dattatreya
# Running for article /wiki/M._M._Hashim
# Running for article /wiki/T._Manemma
# Running for article /wiki/Bakar_Ali_Mirza
# Running for article /wiki/Damodar_Raja_Narasimha
# Running for article /wiki/Satish_Sharma
# Running for article /wiki/P._Shiv_Shankar
# Running for article /wiki/Anjan_Kumar_Yadav
# Running for article /wiki/Allu_Aravind
# Running for article /wiki/T._Anjaiah
# Running for article /wiki/Nerella_Anjaneyulu
# Running for article /wiki/Tadur_Bala_Goud
# Running for article /wiki/Haripriya_Banoth
# Running for article /wiki/Konda_Laxman_Bapuji
# Running for article /wiki/Korukanti_Chandar
# Running for article /wiki/Banoth_Chandravathi
# Running for article /wiki/Chandupatla_Janga_Reddy
# Running for article /wiki/Renuka_Chowdhury
# Running for article /wiki/Bandaru_Dattatreya
# Running for article /wiki/Pasunuri_Dayakar
# Running for article /wiki/Mirza_Riyaz_Ul_Effendi
# Running for article /wiki/Anil_Kumar_Eravathri
# Running for article /wiki/Baba_Fasiuddin
# Running for article /wiki/Gellu_Srinivas_Yadav
# Running for article /wiki/Mohammed_Ghouse
# Running for article /wiki/Mukesh_Goud
# Running for article /wiki/T._Padma_Rao_Goud
# Running for article /wiki/Mynampally_Hanumantha_Rao
# Running for article /wiki/Syed_Aminul_Hasan_Jafri
# Running for article /wiki/Manda_Jagannath
# Running for article /wiki/Kunduru_Jana_Reddy
# Running for article /wiki/Pawan_Kalyan
# Running for article /wiki/Gangula_Kamalakar
# Running for article /wiki/Malik_Motasim_Khan
# Running for article /wiki/Mohammad_Moazam_Khan
# Running for article /wiki/Mumtaz_Ahmed_Khan_(Telangana_politician)
# Running for article /wiki/Gadari_Kishore
# Running for article /wiki/Dileep_Kumar_(politician)
# Running for article /wiki/G._Raj_Kumar
# Running for article /wiki/Joginapally_Santosh_Kumar
# Running for article /wiki/Chellamalla_Suguna_Kumari
# Running for article /wiki/Ponnala_Lakshmaiah
# Running for article /wiki/Endela_Lakshminarayana
# Running for article /wiki/K._Laxman
# Running for article /wiki/Ananthula_Madan_Mohan
# Running for article /wiki/Banoth_Madanlal
# Running for article /wiki/Mohammed_Adam_Mallik
# Running for article /wiki/Kavitha_Maloth
# Running for article /wiki/Muddasani_Damodar_Reddy
# Running for article /wiki/Danam_Nagender
# Running for article /wiki/G._Nagesh
# Running for article /wiki/P._V._Rangaiah_Naidu
# Running for article /wiki/Balram_Naik
# Running for article /wiki/Balu_Naik
# Running for article /wiki/Sitaram_Naik
# Running for article /wiki/Motkupalli_Narasimhulu
# Running for article /wiki/Aelay_Narendra
# Running for article /wiki/Boora_Narsaiah_Goud
# Running for article /wiki/Gummadi_Narsaiah
# Running for article /wiki/Asaduddin_Owaisi
# Running for article /wiki/B._B._Patil
# Running for article /wiki/Political_families_of_Andhra_Pradesh_and_Telangana
# Running for article /wiki/N._V._S._S._Prabhakar
# Running for article /wiki/Ponnam_Prabhakar
# Running for article /wiki/Banda_Prakash
# Running for article /wiki/K._Pushpaleela
# Running for article /wiki/Ragya_Naik
# Running for article /wiki/Siricilla_Rajaiah
# Running for article /wiki/Ravindra_Kumar_Ramavath
# Running for article /wiki/Chennamaneni_Ramesh
# Running for article /wiki/Nyalakonda_Ramkishan_Rao
# Running for article /wiki/Bonthu_Rammohan
# Running for article /wiki/Burgula_Ramakrishna_Rao
# Running for article /wiki/C._Vidyasagar_Rao
# Running for article /wiki/Devarakonda_Vittal_Rao
# Running for article /wiki/Errabelli_Dayakar_Rao
# Running for article /wiki/Garikapati_Mohan_Rao
# Running for article /wiki/Gattu_Ramachandra_Rao
# Running for article /wiki/Jalagam_Venkat_Rao
# Running for article /wiki/K._Chandrashekar_Rao
# Running for article /wiki/K._Keshava_Rao
# Running for article /wiki/K._T._Rama_Rao
# Running for article /wiki/Madhavaram_Krishna_Rao
# Running for article /wiki/Nama_Nageswara_Rao
# Running for article /wiki/N._Ramchander_Rao
# Running for article /wiki/P._V._Ranga_Rao
# Running for article /wiki/Pendyal_Raghava_Rao
# Running for article /wiki/V._Hanumantha_Rao
# Running for article /wiki/Ramesh_Rathod
# Running for article /wiki/Satyavathi_Rathod
# Running for article /wiki/Mallu_Ravi
# Running for article /wiki/A._P._Jithender_Reddy
# Running for article /wiki/Allola_Indrakaran_Reddy
# Running for article /wiki/Asannagari_Jeevan_Reddy
# Running for article /wiki/Baddam_Bal_Reddy
# Running for article /wiki/Bhimreddy_Narasimha_Reddy
# Running for article /wiki/C._Laxma_Reddy
# Running for article /wiki/Chintala_Ramachandra_Reddy
# Running for article /wiki/Gudem_Mahipal_Reddy
# Running for article /wiki/Gutha_Sukender_Reddy
# Running for article /wiki/Jagga_Reddy
# Running for article /wiki/Jaipal_Reddy
# Running for article /wiki/K._V._Subba_Reddy
# Running for article /wiki/Kiran_Kumar_Reddy
# Running for article /wiki/Komatireddy_Raj_Gopal_Reddy
# Running for article /wiki/Komatireddy_Venkat_Reddy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       1 for i in list_final:
#       2     print(f"Running for article {i}")
# ----> 3     extractinfo(i)
#
# Input In [7], in extractinfo(page)
#       1 def extractinfo(page):
# ----> 2     page = requests.get('https://en.wikipedia.org/{}'.format(page), timeout=10)
#       3     # page = requests.get(articleUrl_final, timeout=10)
#       4     soup = BeautifulSoup(page.content, 'html.parser')
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:687, in Session.send(self, request, **kwargs)
#     684         pass
#     686 if not stream:
# --> 687     r.content
#     689 return r
#
# File ~\anaconda3\lib\site-packages\requests\models.py:838, in Response.content(self)
#     836         self._content = None
#     837     else:
# --> 838         self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     840 self._content_consumed = True
#     841 # don't need to release the connection; that's been handled by urllib3
#     842 # since we exhausted the data.
#
# File ~\anaconda3\lib\site-packages\requests\models.py:760, in Response.iter_content.<locals>.generate()
#     758 if hasattr(self.raw, 'stream'):
#     759     try:
# --> 760         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761             yield chunk
#     762     except ProtocolError as e:
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     559 """
#     560 A generator wrapper for the read() method. A call will block until
#     561 ``amt`` bytes have been read from the connection or until the
#    (...)
#     572     'content-encoding' header.
#     573 """
#     574 if self.chunked and self.supports_chunked_reads():
# --> 575     for line in self.read_chunked(amt, decode_content=decode_content):
#     576         yield line
#     577 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:767, in HTTPResponse.read_chunked(self, amt, decode_content)
#     764     return
#     766 while True:
# --> 767     self._update_chunk_length()
#     768     if self.chunk_left == 0:
#     769         break
#
# File ~\anaconda3\lib\site-packages\urllib3\response.py:697, in HTTPResponse._update_chunk_length(self)
#     695 if self.chunk_left is not None:
#     696     return
# --> 697 line = self._fp.fp.readline()
#     698 line = line.split(b";", 1)[0]
#     699 try:
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
data = pd.DataFrame(list_of_info)
data.to_csv('output.csv')
